# %%
from text_to_places import *
from map_places import *
from extract_info import *
import wikipedia
import spacy
import en_core_web_sm
nlp = en_core_web_sm.load()
# Out:
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: cymem.cymem.Pool size changed, may indicate binary incompatibility. Expected 48 from C header, got 64 from PyObject
#   return f(*args, **kwds)
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: cymem.cymem.Address size changed, may indicate binary incompatibility. Expected 24 from C header, got 40 from PyObject
#   return f(*args, **kwds)
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: cymem.cymem.Pool size changed, may indicate binary incompatibility. Expected 48 from C header, got 64 from PyObject
#   return f(*args, **kwds)
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: cymem.cymem.Address size changed, may indicate binary incompatibility. Expected 24 from C header, got 40 from PyObject
#   return f(*args, **kwds)

# %%
markers = ['o', '^', '<', '>', 'v', 's', 'P', '*', 'h', 'D']
colors = ['red', 'orange', 'green', 'blue', 'indigo', 'brown', 'black']
# for i,name in enumerate(['Socrates', 'Karl Marx', 'Groucho Marx', 'Charles Manson', 'Scooby Doo']):
for i,name in enumerate(['Socrates']):
    ax = world.plot(
        color='white', edgecolor='black', figsize=(20, 20)
    )
    doc = wikipedia.page(name)
    text = doc.content[:10000]
    gdf = makeDataFrame(text)

    getTopics(gdf)
    getDates(gdf)
    
    print(name, gdf)
    gdf.to_csv('bios/'+name+'.csv')
    gdf.plot(ax=ax, color=colors[i], alpha=0.25, label=name, marker=markers[i])

    plt.legend()
    plt.savefig('bios/biomap_'+name+'.png')
# Out:
# C:\Users\rowan\Dropbox\programmery\recurse\auto-map-generation\extract_info.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   gdf.topic[i] = topic
# C:\Users\rowan\Dropbox\programmery\recurse\auto-map-generation\extract_info.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   gdf['date'][i] = [x.text for x in sentence.ents if x.label_ == 'DATE'][:1]
# Socrates           text label  idx                                           sentence  \
# 0     Socrates   GPE   16  (Plato, 's, dialogues, are, among, the, most, ...
# 1     Socrates   GPE   19  (Through, his, portrayal, in, Plato, 's, dialo...
# ...

# %%
gdf['text'] = ''

# %%
dfmi = pd.DataFrame([list('abcd'),
                     list('efgh'),
                     list('ijkl'),
                     list('mnop')],
                    columns=pd.MultiIndex.from_product([['one', 'two'],
                                                        ['first', 'second']]))

# %%
dfmi
# Out:
#     one          two
#   first second first second
# 0     a      b     c      d
# 1     e      f     g      h
# 2     i      j     k      l
# 3     m      n     o      p

# %%
dfmi['one']['first'] = 'a'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
