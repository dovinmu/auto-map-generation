# %%
from text_to_places import *
from map_places import *
from extract_info import *
import wikipedia
import spacy
import en_core_web_sm
nlp = en_core_web_sm.load()
# Out:
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: cymem.cymem.Pool size changed, may indicate binary incompatibility. Expected 48 from C header, got 64 from PyObject
#   return f(*args, **kwds)
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: cymem.cymem.Address size changed, may indicate binary incompatibility. Expected 24 from C header, got 40 from PyObject
#   return f(*args, **kwds)
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: cymem.cymem.Pool size changed, may indicate binary incompatibility. Expected 48 from C header, got 64 from PyObject
#   return f(*args, **kwds)
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: cymem.cymem.Address size changed, may indicate binary incompatibility. Expected 24 from C header, got 40 from PyObject
#   return f(*args, **kwds)

# %%
doc = wikipedia.page("Bill Clinton")
text = doc.content
gdf = makeDataFrame(text)

born = ('born', ['was born'])
died = ('died', [' died'])
travel = ('travel', ['went to '' moved', 'set off for', 'traveled', 'returned to' 'travelled', 'visited', 'visit '])
lived = ('lived', [' lived in', ' lived at', ' live in', ' reside ', ' resided', 'residence', 'stayed in', 'stay in', ' spend ', ' spent '])
education = ('education', ['University', 'school ', 'schooling', 'education ', 'educated', 'College', 'graduate', 'graduating', 'worked as a', 'worked at', 'job as', 'jobs'])
parents = ('parents', ['father', ' mother', 'grandfather', 'grand mother', 'grandparents'])

cats = [born, died, travel, lived, education, parents]


getTopics(gdf)
# Out:
# 1/237 the United States
# 2/237 Arkansas
# 3/237 Arkansas
# 4/237 Arkansas
# 5/237 Arkansas
# 6/237 Arkansas
# 7/237 Arkansas
# 8/237 U.S.
# 9/237 U.S.
# 10/237 Kosovo
# 11/237 Northern Ireland
# 12/237 U.S.
# 13/237 U.S.
# 14/237 Haiti
# 15/237 Haiti
# 16/237 North Korea
# 17/237 Pyongyang
# 18/237 Hope
# 19/237 Arkansas
# 20/237 Virginia
# 21/237 New Orleans
# 22/237 United States
# 23/237 Hot Springs
# 24/237 Arkansas
# 25/237 Hot Springs
# 26/237 St. John's
# 27/237 Washington
# 28/237 D.C.
# 29/237 Arkansas
# 30/237 Georgetown
# 31/237 B.Phil
# 32/237 Philosophy
# 33/237 B.Litt
# 34/237 B.Phil
# 35/237 the United States
# 36/237 England
# 37/237 Vietnam
# 38/237 U.S.
# 39/237 Vietnam
# 40/237 Vietnam
# 41/237 Vietnam
# 42/237 United States
# 43/237 California
# 44/237 New Haven
# 45/237 Texas
# 46/237 Rodham
# 47/237 Dallas
# 48/237 Dallas
# 49/237 Texas
# 50/237 Arkansas
# 51/237 1979–1981
# 52/237 Arkansas
# 53/237 Arkansas
# 54/237 Arkansas
# 55/237 Arkansas
# ...
