# %%
import spacy
import en_core_web_sm
from shapely.geometry import Point
# Out:
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: cymem.cymem.Pool size changed, may indicate binary incompatibility. Expected 48 from C header, got 64 from PyObject
#   return f(*args, **kwds)
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: cymem.cymem.Address size changed, may indicate binary incompatibility. Expected 24 from C header, got 40 from PyObject
#   return f(*args, **kwds)

# %%
import text_to_places
from text_to_places import *
# Out:
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: cymem.cymem.Pool size changed, may indicate binary incompatibility. Expected 48 from C header, got 64 from PyObject
#   return f(*args, **kwds)
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: cymem.cymem.Address size changed, may indicate binary incompatibility. Expected 24 from C header, got 40 from PyObject
#   return f(*args, **kwds)

# %%
nlp = en_core_web_sm.load()

# %%
import wikipedia
doc = wikipedia.page("Charles_Darwin")
text = doc.content

# %%
del DependencyParser
from spacy.pipeline import DependencyParser
#parser = DependencyParser(nlp.vocab)
d = nlp(rev.content.strip('\n'))
from spacy.symbols import VERB, nsubj, pobj, PROPN
for x in d:
    if x.ent_type_ in ['GPE', 'LOC'] and x.pos_ == 'PROPN' and x.dep_ == 'pobj' and x.head.text in ['in', 'at']:
           # print(x, x.pos_)
            h = x.head.head
            print(h.pos_)
            if h.pos_ == 'VERB':
                rest = h.subtree
                print(' '.join([w.text for w in rest]))
                print([c for c in h.children if c.dep_ == 'nsubj'], '\n')

# %%
#file = 'don_quixote.txt'
#text = open(file, 'r', encoding='UTF-8').read()

# %%
locations = text_to_places.getLocations(text)
print(locations)
# Out:
# [Shrewsbury, Shropshire, Mount, Shrewsbury, Shropshire, UK, the Firth of Forth, Lamarck, Europe, Cambridge, Cambridge, Wales, Wales, South America, Cambridge, Jago, Cape Verde, Brazil, Patagonia, Megatherium, England, England, England, Chile, Andes, Galápagos Islands, Chile, Australia, Islands, Cape Town, the Falkland Islands, Falmouth, Cornwall, Shrewsbury, Cambridge, London, Megatherium, Glyptodon, South America, Cambridge, Galapagos, London, Geoffroy, Macrauchenia, Galápagos, Shrewsbury, Scotland, Shrewsbury, Marry, London, London, London, London, Cirripedia, Borneo, Dublin, Cambridge, Sedgwick, Britain, Orchids, the Vegetable Kingdom, Mendoza, Argentina, Cambridge, Mount Darwin, Andes, Australia, Australia, the Galápagos Islands, UK, London, Cambridge, Denmark, Sweden, USA, Cambridge, Australia, England, Britain, Evolutionary, Britain, America, Canada, Australia, the United States, South America, Cambridge]

# %%
text_locations = [X.text for X in locations]
print(len(locations))
print(len(set(text_locations)))
# Out:
# 87
# 51

# %%
import geocoder

# %%
# how to make this faster?
latlngs = getLatLng(locations)
# Out:
# 0/87 Shrewsbury
# 1/87 Shropshire
# 2/87 Mount
# 5/87 UK
# 6/87 the Firth of Forth
# 7/87 Lamarck
# 8/87 Europe
# 9/87 Cambridge
# 11/87 Wales
# 13/87 South America
# 15/87 Jago
# 16/87 Cape Verde
# 17/87 Brazil
# 18/87 Patagonia
# 19/87 Megatherium
# 20/87 England
# 23/87 Chile
# 24/87 Andes
# 25/87 Galápagos Islands
# 27/87 Australia
# 28/87 Islands
# 29/87 Cape Town
# 30/87 the Falkland Islands
# 31/87 Falmouth
# 32/87 Cornwall
# 35/87 London
# 37/87 Glyptodon
# 40/87 Galapagos
# 42/87 Geoffroy
# 43/87 Macrauchenia
# 44/87 Galápagos
# 46/87 Scotland
# 48/87 Marry
# 53/87 Cirripedia
# 54/87 Borneo
# 55/87 Dublin
# 57/87 Sedgwick
# 58/87 Britain
# 59/87 Orchids
# 60/87 the Vegetable Kingdom
# 61/87 Mendoza
# 62/87 Argentina
# 64/87 Mount Darwin
# 68/87 the Galápagos Islands
# 72/87 Denmark
# 73/87 Sweden
# 74/87 USA
# 79/87 Evolutionary
# 81/87 America
# 82/87 Canada
# 84/87 the United States

# %%
print(set(text_locations))
# Out:
# {'Orchids', 'the Vegetable Kingdom', 'Denmark', 'Lamarck', 'Evolutionary', 'Europe', 'Canada', 'USA', 'the Falkland Islands', 'Islands', 'Dublin', 'Cape Verde', 'Cape Town', 'South America', 'Cirripedia', 'Mendoza', 'the Galápagos Islands', 'Wales', 'Scotland', 'Sedgwick', 'Jago', 'Chile', 'Argentina', 'Brazil', 'Geoffroy', 'Andes', 'England', 'Britain', 'Mount Darwin', 'Sweden', 'Mount', 'Macrauchenia', 'Borneo', 'Galápagos', 'America', 'Glyptodon', 'Galápagos Islands', 'Shropshire', 'Shrewsbury', 'London', 'Cornwall', 'the United States', 'the Firth of Forth', 'Marry', 'Australia', 'Patagonia', 'Cambridge', 'Falmouth', 'Galapagos', 'UK', 'Megatherium'}

# %%
import geopandas as gpd
import pandas as pd

# %%
latlngs
# Out:
# {'Shrewsbury': <shapely.geometry.point.Point at 0x19104217c50>,
#  'Shropshire': <shapely.geometry.point.Point at 0x19123604630>,
#  'Mount': <shapely.geometry.point.Point at 0x191235e8630>,
#  'UK': <shapely.geometry.point.Point at 0x1912360a668>,
#  'the Firth of Forth': <shapely.geometry.point.Point at 0x1912360a6d8>,
#  'Lamarck': <shapely.geometry.point.Point at 0x1912360a710>,
#  'Europe': <shapely.geometry.point.Point at 0x1912360a748>,
#  'Cambridge': <shapely.geometry.point.Point at 0x1912360a780>,
#  'Wales': <shapely.geometry.point.Point at 0x1912360a828>,
#  'South America': <shapely.geometry.point.Point at 0x1912360a7f0>,
#  'Jago': <shapely.geometry.point.Point at 0x1912360a7b8>,
#  'Cape Verde': <shapely.geometry.point.Point at 0x1912360a860>,
#  'Brazil': <shapely.geometry.point.Point at 0x1912360a898>,
#  'Patagonia': <shapely.geometry.point.Point at 0x1912360a8d0>,
#  'England': <shapely.geometry.point.Point at 0x1912360a908>,
#  'Chile': <shapely.geometry.point.Point at 0x1912360a940>,
#  'Andes': <shapely.geometry.point.Point at 0x1912360a978>,
#  'Galápagos Islands': <shapely.geometry.point.Point at 0x1912360a9b0>,
#  'Australia': <shapely.geometry.point.Point at 0x1912360a9e8>,
#  'Islands': <shapely.geometry.point.Point at 0x1912360aa20>,
#  'Cape Town': <shapely.geometry.point.Point at 0x1912360aa58>,
#  'the Falkland Islands': <shapely.geometry.point.Point at 0x1912360aa90>,
#  'Falmouth': <shapely.geometry.point.Point at 0x1912360aac8>,
#  'Cornwall': <shapely.geometry.point.Point at 0x1912360ab00>,
#  'London': <shapely.geometry.point.Point at 0x1912360ab38>,
#  'Galapagos': <shapely.geometry.point.Point at 0x1912360ab70>,
#  'Geoffroy': <shapely.geometry.point.Point at 0x1912360aba8>,
#  'Galápagos': <shapely.geometry.point.Point at 0x1912360abe0>,
#  'Scotland': <shapely.geometry.point.Point at 0x1912360ac18>,
#  'Marry': <shapely.geometry.point.Point at 0x1912360ac50>,
#  'Borneo': <shapely.geometry.point.Point at 0x1912360ac88>,
#  'Dublin': <shapely.geometry.point.Point at 0x1912360acc0>,
#  'Sedgwick': <shapely.geometry.point.Point at 0x1912360acf8>,
#  'Britain': <shapely.geometry.point.Point at 0x1912360ad30>,
#  'Orchids': <shapely.geometry.point.Point at 0x1912360ad68>,
#  'Mendoza': <shapely.geometry.point.Point at 0x1912360ada0>,
#  'Argentina': <shapely.geometry.point.Point at 0x1912360add8>,
#  'Mount Darwin': <shapely.geometry.point.Point at 0x1912360ae10>,
#  'the Galápagos Islands': <shapely.geometry.point.Point at 0x1912360ae48>,
#  'Denmark': <shapely.geometry.point.Point at 0x1912360ae80>,
#  'Sweden': <shapely.geometry.point.Point at 0x1912360aeb8>,
#  'USA': <shapely.geometry.point.Point at 0x1912360aef0>,
#  'Evolutionary': <shapely.geometry.point.Point at 0x1912360af28>,
#  'America': <shapely.geometry.point.Point at 0x1912360af60>,
#  'Canada': <shapely.geometry.point.Point at 0x1912360afd0>,
#  'the United States': <shapely.geometry.point.Point at 0x1912360af98>}

# %%
import map_places
from map_places import *

# %%
gdf = getDataFrame(latlngs)
gdf
# Out:
#                                                    Coordinates
# Shrewsbury                       POINT (-2.7540094 52.7078866)
# Shropshire               POINT (-2.64356407027027 52.65233935)
# Mount                            POINT (14.4476911 35.8885993)
# UK                               POINT (-3.2765753 54.7023545)
# the Firth of Forth               POINT (-3.2299899 56.0208894)
# Lamarck                        POINT (-71.4601806 -33.0538669)
# Europe                                           POINT (10 51)
# Cambridge                         POINT (0.1235817 52.2034823)
# Wales                              POINT (-3.73893 52.2928116)
# South America                  POINT (-61.0006565 -21.0002179)
# Jago                     POINT (-97.14917989999999 33.1737309)
# Cape Verde                      POINT (-24.0083947 16.0000552)
# Brazil                               POINT (-53.2 -10.3333333)
# Patagonia              POINT (-70.81737413544229 -44.99028505)
# England                  POINT (-0.540240286617432 52.7954791)
# Chile                          POINT (-71.3187697 -31.7613365)
# Andes                          POINT (-70.0118233 -32.6529485)
# Galápagos Islands            POINT (-90.3642695454545 -0.6288)
# Australia                          POINT (134.755 -24.7761086)
# Islands                         POINT (-96.7599994 33.8389917)
# Cape Town                         POINT (18.417396 -33.928992)
# the Falkland Islands           POINT (-64.9672817 -34.9964963)
# Falmouth                         POINT (-5.0688262 50.1552197)
# Cornwall                               POINT (-4.75 50.416667)
# London                           POINT (-0.1276474 51.5073219)
# Galapagos                        POINT (-3.3379593 40.6965903)
# Geoffroy                        POINT (-79.2215952 47.4919046)
# Galápagos                        POINT (-3.3379593 40.6965903)
# Scotland                         POINT (-4.1140518 56.7861112)
# Marry                             POINT (0.1401709 44.3465908)
# Borneo                     POINT (114.740599198093 1.42965855)
# Dublin                           POINT (-6.2602732 53.3497645)
# Sedgwick                        POINT (-97.4641388 37.6448148)
# Britain                          POINT (-3.2765753 54.7023545)
# Orchids                  POINT (124.2668392 8.258362099999999)
# Mendoza                        POINT (-68.8442956 -32.8897294)
# Argentina                      POINT (-64.9672817 -34.9964963)
# Mount Darwin             POINT (31.6393395386574 -16.54064295)
# the Galápagos Islands        POINT (-90.3642695454545 -0.6288)
# Denmark                           POINT (10.3333283 55.670249)
# Sweden                           POINT (14.5208584 59.6749712)
# USA                            POINT (-100.4458825 39.7837304)
# Evolutionary                       POINT (-2.625799 51.477925)
# America                  POINT (-59.0017622330522 -27.4351024)
# Canada                         POINT (-107.9917071 61.0666922)
# the United States              POINT (-100.4458825 39.7837304)

# %%
import matplotlib.pyplot as plt

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
# %matplotlib inline
import numpy as np
from scipy import ndimage

import matplotlib.pylab as pylab
import matplotlib.pyplot as plt
#pylab.rcParams['figure.figsize'] = 8, 6

ax = world.plot(
    color='white', edgecolor='black', figsize= (12,12), alpha=0.15
)

def heatmap(d, bins=(400,400), smoothing=3, cmap='Greys'):
    def getx(pt):
        return pt.coords[0][0]

    def gety(pt):
        return pt.coords[0][1]

    x = list(d.geometry.apply(getx))
    y = list(d.geometry.apply(gety))
    heatmap, xedges, yedges = np.histogram2d(y, x, bins=bins)
    extent = [yedges[0], yedges[-1], xedges[-1], xedges[0]]
    #extent = (-180,180,-90,90)
    logheatmap = np.log(heatmap)
    logheatmap[np.isneginf(logheatmap)] = 0
    logheatmap = ndimage.filters.gaussian_filter(logheatmap, smoothing, mode='nearest')
    
    plt.imshow(logheatmap, cmap=cmap, extent=extent)
    #plt.colorbar()
    plt.gca().invert_yaxis()
    
    plt.xlim(-120, 50)
    plt.ylim(-75, 75)
    plt.show()
    
heatmap(gdf)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: RuntimeWarning: divide by zero encountered in log

# %%
# ax = world.plot(
#     color='white', edgecolor='black', figsize= (12,12)
# )

# gdf.plot(ax=ax, color='red')
# for idx,row in gdf.iterrows():
#     text_coords = [arr.tolist()[0] for arr in row.Coordinates.xy]
#     plt.annotate(s=idx, xy=text_coords, horizontalalignment='center', size="medium")

# plt.xlim(-180, 180)
# plt.ylim(-90, 90)
# plt.show()
