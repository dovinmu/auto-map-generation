# %%
from text_to_places import *
from map_places import *
# Out:
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: cymem.cymem.Pool size changed, may indicate binary incompatibility. Expected 48 from C header, got 64 from PyObject
#   return f(*args, **kwds)
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: cymem.cymem.Address size changed, may indicate binary incompatibility. Expected 24 from C header, got 40 from PyObject
#   return f(*args, **kwds)
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: cymem.cymem.Pool size changed, may indicate binary incompatibility. Expected 48 from C header, got 64 from PyObject
#   return f(*args, **kwds)
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: cymem.cymem.Address size changed, may indicate binary incompatibility. Expected 24 from C header, got 40 from PyObject
#   return f(*args, **kwds)

# %%
import wikipedia
doc = wikipedia.page("Charles_Darwin")
text = doc.content

# %%
import spacy
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
gdf = makeDataFrame(text)
# Out:
# 1/87 Shrewsbury
# 2/87 Shropshire
# 3/87 Mount
# 4/87 Shrewsbury
# 5/87 Shropshire
# 6/87 UK
# 7/87 the Firth of Forth
# 8/87 Lamarck
# 9/87 Europe
# 10/87 Cambridge
# 11/87 Cambridge
# 12/87 Wales
# 13/87 Wales
# 14/87 South America
# 15/87 Cambridge
# 16/87 Jago
# 17/87 Cape Verde
# 18/87 Brazil
# 19/87 Patagonia
# 20/87 Megatherium
# 21/87 England
# 22/87 England
# 23/87 England
# 24/87 Chile
# 25/87 Andes
# 26/87 Galápagos Islands
# 27/87 Chile
# 28/87 Australia
# 29/87 Islands
# 30/87 Cape Town
# 31/87 the Falkland Islands
# 32/87 Falmouth
# 33/87 Cornwall
# 34/87 Shrewsbury
# 35/87 Cambridge
# 36/87 London
# 37/87 Megatherium
# 38/87 Glyptodon
# 39/87 South America
# 40/87 Cambridge
# 41/87 Galapagos
# 42/87 London
# 43/87 Geoffroy
# 44/87 Macrauchenia
# 45/87 Galápagos
# 46/87 Shrewsbury
# 47/87 Scotland
# 48/87 Shrewsbury
# 49/87 Marry
# 50/87 London
# 51/87 London
# 52/87 London
# 53/87 London
# 54/87 Cirripedia
# 55/87 Borneo
# 56/87 Dublin
# 57/87 Cambridge
# 58/87 Sedgwick
# 59/87 Britain
# 60/87 Orchids
# 61/87 the Vegetable Kingdom
# 62/87 Mendoza
# 63/87 Argentina
# 64/87 Cambridge
# 65/87 Mount Darwin
# 66/87 Andes
# 67/87 Australia
# 68/87 Australia
# 69/87 the Galápagos Islands
# 70/87 UK
# 71/87 London
# 72/87 Cambridge
# 73/87 Denmark
# 74/87 Sweden
# 75/87 USA
# 76/87 Cambridge
# 77/87 Australia
# 78/87 England
# 79/87 Britain
# 80/87 Evolutionary
# 81/87 Britain
# 82/87 America
# 83/87 Canada
# 84/87 Australia
# 85/87 the United States
# 86/87 South America
# 87/87 Cambridge

# %%
heatmap(gdf)
# Out:
# C:\Users\rowan\Dropbox\programmery\recurse\auto-map-generation\map_places.py:45: RuntimeWarning: divide by zero encountered in log
#   logheatmap = np.log(heatmap)

# %%
gdf['category'] = gdf.idx.map(lambda i: int(i/200))

# %%
gdf.iloc[4].sentence
# Out:
# Darwin spent the summer of 1825 as an apprentice doctor, helping his father treat the poor of Shropshire, before going to the University of Edinburgh Medical School (at the time the best medical school in the UK) with his brother Erasmus in October 1825.

# %%
ax = world.plot(
    color='white', edgecolor='black', figsize=(20,20)
)
colors = ['red', 'orange', 'green', 'blue', 'indigo', 'purple', 'brown']
for i,cat in enumerate(gdf.category.unique()):
    gdf[gdf.category == cat].plot(ax=ax, color=colors[i%len(colors)], label=cat, alpha=0.25)
plt.legend()
plt.show()
